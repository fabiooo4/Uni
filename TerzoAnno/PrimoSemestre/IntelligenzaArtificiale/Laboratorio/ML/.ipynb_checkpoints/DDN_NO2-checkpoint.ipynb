# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics
# Out:
# 2026-01-23 15:08:08.799545: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /nix/store/lm1dh50a59200g0c4nl175nysy9nxrgh-python3-3.13.11-env/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(40, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), all activation functions should be ReLU.

# %%
def create_model_tiny(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(3, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium(input_size):
    # create model
    model = Sequential()    
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matrix among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() #n_df=n_df.values

#divide predictors from features
X = n_df[:, 1:]; # All features (cols from 2 to 8)
y = n_df[:, 0]; # Only predictors (col 1)

print("df shape ", n_df.shape)
print("X shape ", X.shape)
print("y shape ", y.shape)

seed = 7
np.random.seed(seed)

# split dataset in 77% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);#insert your code here

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_large(X_train.shape[1])
model.summary()
# Out:
# df shape  (500, 8)
# X shape  (500, 7)
# y shape  (500,)
# /nix/store/lm1dh50a59200g0c4nl175nysy9nxrgh-python3-3.13.11-env/lib/python3.13/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           330 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 40)             │         1,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            41 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,691 (6.61 KB)
#  Trainable params: 1,691 (6.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 12.9887 - mean_absolute_error: 3.5155 - val_loss: 11.8236 - val_mean_absolute_error: 3.3462
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.2500 - mean_absolute_error: 3.2560 - val_loss: 9.9350 - val_mean_absolute_error: 3.0449
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2880 - mean_absolute_error: 2.9368 - val_loss: 7.8361 - val_mean_absolute_error: 2.6733
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1435 - mean_absolute_error: 2.5399 - val_loss: 5.5990 - val_mean_absolute_error: 2.2385
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8727 - mean_absolute_error: 2.0459 - val_loss: 3.4730 - val_mean_absolute_error: 1.7504
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8651 - mean_absolute_error: 1.5100 - val_loss: 1.8719 - val_mean_absolute_error: 1.2361
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5240 - mean_absolute_error: 1.0336 - val_loss: 1.1480 - val_mean_absolute_error: 0.8336
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9831 - mean_absolute_error: 0.7642 - val_loss: 0.9681 - val_mean_absolute_error: 0.6896
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8263 - mean_absolute_error: 0.6864 - val_loss: 0.8011 - val_mean_absolute_error: 0.6308
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6719 - mean_absolute_error: 0.6289 - val_loss: 0.6385 - val_mean_absolute_error: 0.5889
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5624 - mean_absolute_error: 0.5728 - val_loss: 0.5671 - val_mean_absolute_error: 0.5765
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5022 - mean_absolute_error: 0.5432 - val_loss: 0.5265 - val_mean_absolute_error: 0.5559
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4596 - mean_absolute_error: 0.5184 - val_loss: 0.4991 - val_mean_absolute_error: 0.5443
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4304 - mean_absolute_error: 0.4982 - val_loss: 0.4777 - val_mean_absolute_error: 0.5315
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4101 - mean_absolute_error: 0.4863 - val_loss: 0.4597 - val_mean_absolute_error: 0.5224
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3931 - mean_absolute_error: 0.4774 - val_loss: 0.4425 - val_mean_absolute_error: 0.5178
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3775 - mean_absolute_error: 0.4681 - val_loss: 0.4314 - val_mean_absolute_error: 0.5149
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3649 - mean_absolute_error: 0.4609 - val_loss: 0.4203 - val_mean_absolute_error: 0.5081
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3529 - mean_absolute_error: 0.4545 - val_loss: 0.4116 - val_mean_absolute_error: 0.5050
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3450 - mean_absolute_error: 0.4484 - val_loss: 0.4036 - val_mean_absolute_error: 0.4984
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3357 - mean_absolute_error: 0.4438 - val_loss: 0.3960 - val_mean_absolute_error: 0.4972
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3300 - mean_absolute_error: 0.4414 - val_loss: 0.3888 - val_mean_absolute_error: 0.4952
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3240 - mean_absolute_error: 0.4388 - val_loss: 0.3834 - val_mean_absolute_error: 0.4915
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3197 - mean_absolute_error: 0.4345 - val_loss: 0.3799 - val_mean_absolute_error: 0.4876
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3150 - mean_absolute_error: 0.4321 - val_loss: 0.3750 - val_mean_absolute_error: 0.4856
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3098 - mean_absolute_error: 0.4289 - val_loss: 0.3720 - val_mean_absolute_error: 0.4834
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3062 - mean_absolute_error: 0.4267 - val_loss: 0.3693 - val_mean_absolute_error: 0.4832
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3043 - mean_absolute_error: 0.4267 - val_loss: 0.3684 - val_mean_absolute_error: 0.4849
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3009 - mean_absolute_error: 0.4241 - val_loss: 0.3646 - val_mean_absolute_error: 0.4806
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2979 - mean_absolute_error: 0.4209 - val_loss: 0.3622 - val_mean_absolute_error: 0.4759
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2973 - mean_absolute_error: 0.4201 - val_loss: 0.3581 - val_mean_absolute_error: 0.4727
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2927 - mean_absolute_error: 0.4173 - val_loss: 0.3529 - val_mean_absolute_error: 0.4721
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2912 - mean_absolute_error: 0.4168 - val_loss: 0.3518 - val_mean_absolute_error: 0.4683
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2895 - mean_absolute_error: 0.4147 - val_loss: 0.3519 - val_mean_absolute_error: 0.4650
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2872 - mean_absolute_error: 0.4137 - val_loss: 0.3485 - val_mean_absolute_error: 0.4674
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2844 - mean_absolute_error: 0.4133 - val_loss: 0.3469 - val_mean_absolute_error: 0.4674
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2827 - mean_absolute_error: 0.4118 - val_loss: 0.3457 - val_mean_absolute_error: 0.4667
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2810 - mean_absolute_error: 0.4106 - val_loss: 0.3435 - val_mean_absolute_error: 0.4659
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2815 - mean_absolute_error: 0.4112 - val_loss: 0.3459 - val_mean_absolute_error: 0.4665
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2781 - mean_absolute_error: 0.4083 - val_loss: 0.3459 - val_mean_absolute_error: 0.4651
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2768 - mean_absolute_error: 0.4071 - val_loss: 0.3435 - val_mean_absolute_error: 0.4625
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2764 - mean_absolute_error: 0.4067 - val_loss: 0.3414 - val_mean_absolute_error: 0.4618
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2756 - mean_absolute_error: 0.4066 - val_loss: 0.3389 - val_mean_absolute_error: 0.4613
# Epoch 44/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2718 - mean_absolute_error: 0.4042 - val_loss: 0.3384 - val_mean_absolute_error: 0.4587
# Epoch 45/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2712 - mean_absolute_error: 0.4033 - val_loss: 0.3374 - val_mean_absolute_error: 0.4566
# Epoch 46/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2702 - mean_absolute_error: 0.4025 - val_loss: 0.3364 - val_mean_absolute_error: 0.4548
# Epoch 47/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2689 - mean_absolute_error: 0.4018 - val_loss: 0.3381 - val_mean_absolute_error: 0.4553
# Epoch 48/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2679 - mean_absolute_error: 0.4015 - val_loss: 0.3371 - val_mean_absolute_error: 0.4570
# Epoch 49/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2662 - mean_absolute_error: 0.4001 - val_loss: 0.3370 - val_mean_absolute_error: 0.4582
# Epoch 50/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2650 - mean_absolute_error: 0.3986 - val_loss: 0.3367 - val_mean_absolute_error: 0.4582
# Epoch 51/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2649 - mean_absolute_error: 0.3989 - val_loss: 0.3345 - val_mean_absolute_error: 0.4553
# Epoch 52/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2623 - mean_absolute_error: 0.3981 - val_loss: 0.3331 - val_mean_absolute_error: 0.4549
# Epoch 53/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2620 - mean_absolute_error: 0.3974 - val_loss: 0.3344 - val_mean_absolute_error: 0.4554
# Epoch 54/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2608 - mean_absolute_error: 0.3984 - val_loss: 0.3330 - val_mean_absolute_error: 0.4545
# Epoch 55/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2580 - mean_absolute_error: 0.3952 - val_loss: 0.3320 - val_mean_absolute_error: 0.4541
# Epoch 56/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2597 - mean_absolute_error: 0.3950 - val_loss: 0.3321 - val_mean_absolute_error: 0.4532
# Epoch 57/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2570 - mean_absolute_error: 0.3923 - val_loss: 0.3301 - val_mean_absolute_error: 0.4509
# Epoch 58/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2572 - mean_absolute_error: 0.3953 - val_loss: 0.3286 - val_mean_absolute_error: 0.4496
# Epoch 59/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2572 - mean_absolute_error: 0.3946 - val_loss: 0.3284 - val_mean_absolute_error: 0.4504
# Epoch 60/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2606 - mean_absolute_error: 0.3947 - val_loss: 0.3358 - val_mean_absolute_error: 0.4538
# Epoch 61/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2551 - mean_absolute_error: 0.3935 - val_loss: 0.3331 - val_mean_absolute_error: 0.4528
# Epoch 62/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2549 - mean_absolute_error: 0.3928 - val_loss: 0.3312 - val_mean_absolute_error: 0.4540
# Epoch 63/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2520 - mean_absolute_error: 0.3901 - val_loss: 0.3308 - val_mean_absolute_error: 0.4545
# Epoch 64/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2518 - mean_absolute_error: 0.3900 - val_loss: 0.3308 - val_mean_absolute_error: 0.4544
# Epoch 65/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2569 - mean_absolute_error: 0.3926 - val_loss: 0.3325 - val_mean_absolute_error: 0.4560
# Epoch 66/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2527 - mean_absolute_error: 0.3916 - val_loss: 0.3275 - val_mean_absolute_error: 0.4550
# Epoch 67/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2492 - mean_absolute_error: 0.3888 - val_loss: 0.3267 - val_mean_absolute_error: 0.4543
# Epoch 68/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2494 - mean_absolute_error: 0.3891 - val_loss: 0.3277 - val_mean_absolute_error: 0.4534
# Epoch 69/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2480 - mean_absolute_error: 0.3884 - val_loss: 0.3311 - val_mean_absolute_error: 0.4539
# Epoch 70/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2452 - mean_absolute_error: 0.3863 - val_loss: 0.3285 - val_mean_absolute_error: 0.4557
# Epoch 71/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2484 - mean_absolute_error: 0.3903 - val_loss: 0.3256 - val_mean_absolute_error: 0.4538
# Epoch 72/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2453 - mean_absolute_error: 0.3856 - val_loss: 0.3249 - val_mean_absolute_error: 0.4496
# Epoch 73/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2456 - mean_absolute_error: 0.3869 - val_loss: 0.3257 - val_mean_absolute_error: 0.4483
# Epoch 74/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2439 - mean_absolute_error: 0.3850 - val_loss: 0.3296 - val_mean_absolute_error: 0.4478
# Epoch 75/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2424 - mean_absolute_error: 0.3840 - val_loss: 0.3262 - val_mean_absolute_error: 0.4489
# Epoch 76/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2428 - mean_absolute_error: 0.3848 - val_loss: 0.3264 - val_mean_absolute_error: 0.4492
# Epoch 77/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2430 - mean_absolute_error: 0.3838 - val_loss: 0.3240 - val_mean_absolute_error: 0.4498
# Epoch 78/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2457 - mean_absolute_error: 0.3872 - val_loss: 0.3215 - val_mean_absolute_error: 0.4490
# Epoch 79/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2420 - mean_absolute_error: 0.3870 - val_loss: 0.3244 - val_mean_absolute_error: 0.4513
# Epoch 80/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2402 - mean_absolute_error: 0.3836 - val_loss: 0.3228 - val_mean_absolute_error: 0.4466
# Epoch 81/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2393 - mean_absolute_error: 0.3800 - val_loss: 0.3243 - val_mean_absolute_error: 0.4471
# Epoch 82/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2386 - mean_absolute_error: 0.3793 - val_loss: 0.3241 - val_mean_absolute_error: 0.4457
# Epoch 83/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2382 - mean_absolute_error: 0.3787 - val_loss: 0.3226 - val_mean_absolute_error: 0.4454
# Epoch 84/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2379 - mean_absolute_error: 0.3793 - val_loss: 0.3246 - val_mean_absolute_error: 0.4452
# Epoch 85/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2371 - mean_absolute_error: 0.3792 - val_loss: 0.3243 - val_mean_absolute_error: 0.4445
# Epoch 86/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2371 - mean_absolute_error: 0.3788 - val_loss: 0.3242 - val_mean_absolute_error: 0.4430
# Epoch 87/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2365 - mean_absolute_error: 0.3767 - val_loss: 0.3268 - val_mean_absolute_error: 0.4466
# Epoch 88/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2360 - mean_absolute_error: 0.3764 - val_loss: 0.3256 - val_mean_absolute_error: 0.4461
# Epoch 89/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2361 - mean_absolute_error: 0.3783 - val_loss: 0.3249 - val_mean_absolute_error: 0.4459
# Epoch 90/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2353 - mean_absolute_error: 0.3795 - val_loss: 0.3240 - val_mean_absolute_error: 0.4464
# Epoch 91/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2339 - mean_absolute_error: 0.3784 - val_loss: 0.3263 - val_mean_absolute_error: 0.4485
# Epoch 92/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2327 - mean_absolute_error: 0.3759 - val_loss: 0.3271 - val_mean_absolute_error: 0.4493
# Epoch 93/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2360 - mean_absolute_error: 0.3759 - val_loss: 0.3280 - val_mean_absolute_error: 0.4480
# Epoch 94/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2343 - mean_absolute_error: 0.3758 - val_loss: 0.3286 - val_mean_absolute_error: 0.4480
# Epoch 95/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2326 - mean_absolute_error: 0.3746 - val_loss: 0.3297 - val_mean_absolute_error: 0.4479
# Epoch 96/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2324 - mean_absolute_error: 0.3747 - val_loss: 0.3271 - val_mean_absolute_error: 0.4475
# Epoch 97/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2310 - mean_absolute_error: 0.3739 - val_loss: 0.3292 - val_mean_absolute_error: 0.4485
# Epoch 98/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2306 - mean_absolute_error: 0.3745 - val_loss: 0.3293 - val_mean_absolute_error: 0.4498
# Epoch 99/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2309 - mean_absolute_error: 0.3740 - val_loss: 0.3280 - val_mean_absolute_error: 0.4484
# Epoch 100/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2309 - mean_absolute_error: 0.3742 - val_loss: 0.3306 - val_mean_absolute_error: 0.4470
# Epoch 101/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2350 - mean_absolute_error: 0.3752 - val_loss: 0.3414 - val_mean_absolute_error: 0.4542
# Epoch 102/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2278 - mean_absolute_error: 0.3710 - val_loss: 0.3295 - val_mean_absolute_error: 0.4446
# Epoch 103/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2318 - mean_absolute_error: 0.3764 - val_loss: 0.3281 - val_mean_absolute_error: 0.4470
# Epoch 104/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2275 - mean_absolute_error: 0.3714 - val_loss: 0.3277 - val_mean_absolute_error: 0.4495
# Epoch 105/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2291 - mean_absolute_error: 0.3718 - val_loss: 0.3258 - val_mean_absolute_error: 0.4479
# Epoch 106/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2270 - mean_absolute_error: 0.3729 - val_loss: 0.3279 - val_mean_absolute_error: 0.4460
# Epoch 107/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2305 - mean_absolute_error: 0.3766 - val_loss: 0.3314 - val_mean_absolute_error: 0.4462
# Epoch 108/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2272 - mean_absolute_error: 0.3703 - val_loss: 0.3369 - val_mean_absolute_error: 0.4497
# Epoch 109/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2255 - mean_absolute_error: 0.3697 - val_loss: 0.3307 - val_mean_absolute_error: 0.4467
# Epoch 110/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2242 - mean_absolute_error: 0.3680 - val_loss: 0.3308 - val_mean_absolute_error: 0.4497
# Epoch 111/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2241 - mean_absolute_error: 0.3682 - val_loss: 0.3281 - val_mean_absolute_error: 0.4473
# Epoch 112/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2259 - mean_absolute_error: 0.3691 - val_loss: 0.3249 - val_mean_absolute_error: 0.4461
# Epoch 113/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2240 - mean_absolute_error: 0.3682 - val_loss: 0.3284 - val_mean_absolute_error: 0.4464
# Epoch 114/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2308 - mean_absolute_error: 0.3708 - val_loss: 0.3313 - val_mean_absolute_error: 0.4495
# Epoch 115/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2250 - mean_absolute_error: 0.3693 - val_loss: 0.3292 - val_mean_absolute_error: 0.4478
# Epoch 116/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2247 - mean_absolute_error: 0.3679 - val_loss: 0.3369 - val_mean_absolute_error: 0.4533
# Epoch 117/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2220 - mean_absolute_error: 0.3642 - val_loss: 0.3295 - val_mean_absolute_error: 0.4469
# Epoch 118/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2226 - mean_absolute_error: 0.3690 - val_loss: 0.3319 - val_mean_absolute_error: 0.4483
# Epoch 119/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2207 - mean_absolute_error: 0.3667 - val_loss: 0.3337 - val_mean_absolute_error: 0.4491
# Epoch 120/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2236 - mean_absolute_error: 0.3683 - val_loss: 0.3390 - val_mean_absolute_error: 0.4508
# Epoch 121/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2231 - mean_absolute_error: 0.3668 - val_loss: 0.3345 - val_mean_absolute_error: 0.4462
# Epoch 122/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2192 - mean_absolute_error: 0.3635 - val_loss: 0.3383 - val_mean_absolute_error: 0.4490
# Epoch 123/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2195 - mean_absolute_error: 0.3633 - val_loss: 0.3343 - val_mean_absolute_error: 0.4477
# Epoch 124/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2198 - mean_absolute_error: 0.3640 - val_loss: 0.3349 - val_mean_absolute_error: 0.4506
# Epoch 125/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2219 - mean_absolute_error: 0.3688 - val_loss: 0.3320 - val_mean_absolute_error: 0.4467
# Epoch 126/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2195 - mean_absolute_error: 0.3656 - val_loss: 0.3341 - val_mean_absolute_error: 0.4485
# Epoch 127/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2186 - mean_absolute_error: 0.3639 - val_loss: 0.3368 - val_mean_absolute_error: 0.4471
# Epoch 128/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2164 - mean_absolute_error: 0.3627 - val_loss: 0.3380 - val_mean_absolute_error: 0.4494
# Epoch 129/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2193 - mean_absolute_error: 0.3624 - val_loss: 0.3329 - val_mean_absolute_error: 0.4477
# Epoch 130/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2141 - mean_absolute_error: 0.3616 - val_loss: 0.3298 - val_mean_absolute_error: 0.4440
# Epoch 131/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2156 - mean_absolute_error: 0.3627 - val_loss: 0.3309 - val_mean_absolute_error: 0.4455
# Epoch 132/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2147 - mean_absolute_error: 0.3588 - val_loss: 0.3372 - val_mean_absolute_error: 0.4452
# Epoch 133/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2144 - mean_absolute_error: 0.3587 - val_loss: 0.3405 - val_mean_absolute_error: 0.4450
# Epoch 134/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2148 - mean_absolute_error: 0.3594 - val_loss: 0.3392 - val_mean_absolute_error: 0.4445
# Epoch 135/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2154 - mean_absolute_error: 0.3570 - val_loss: 0.3356 - val_mean_absolute_error: 0.4435
# Epoch 136/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2158 - mean_absolute_error: 0.3616 - val_loss: 0.3297 - val_mean_absolute_error: 0.4428
# Epoch 137/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2132 - mean_absolute_error: 0.3570 - val_loss: 0.3344 - val_mean_absolute_error: 0.4490
# Epoch 138/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2128 - mean_absolute_error: 0.3579 - val_loss: 0.3362 - val_mean_absolute_error: 0.4504
# Epoch 139/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2120 - mean_absolute_error: 0.3566 - val_loss: 0.3408 - val_mean_absolute_error: 0.4546
# Epoch 140/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2131 - mean_absolute_error: 0.3585 - val_loss: 0.3384 - val_mean_absolute_error: 0.4522
# Epoch 141/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2103 - mean_absolute_error: 0.3573 - val_loss: 0.3435 - val_mean_absolute_error: 0.4537
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2109 - mean_absolute_error: 0.3586 - val_loss: 0.3438 - val_mean_absolute_error: 0.4508
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2102 - mean_absolute_error: 0.3574 - val_loss: 0.3482 - val_mean_absolute_error: 0.4540
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2118 - mean_absolute_error: 0.3559 - val_loss: 0.3430 - val_mean_absolute_error: 0.4504
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2110 - mean_absolute_error: 0.3547 - val_loss: 0.3457 - val_mean_absolute_error: 0.4489
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2124 - mean_absolute_error: 0.3550 - val_loss: 0.3422 - val_mean_absolute_error: 0.4470
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2071 - mean_absolute_error: 0.3510 - val_loss: 0.3359 - val_mean_absolute_error: 0.4437
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2083 - mean_absolute_error: 0.3540 - val_loss: 0.3418 - val_mean_absolute_error: 0.4450
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2100 - mean_absolute_error: 0.3576 - val_loss: 0.3433 - val_mean_absolute_error: 0.4491
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2056 - mean_absolute_error: 0.3534 - val_loss: 0.3517 - val_mean_absolute_error: 0.4581

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# rmse :  0.5545196519479865   nrmse :  0.2745856833375132

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()

# %% [markdown]
# # Quiz Machine learning
# ## Question 1 (question 5 of reinforced learning quiz)
# Consider a regression task using Deep Neural Networks (DNNs) and consider the dataset NO2 (the same code as the ML laboratory). Create a DNN consisting of three hidden layers, each of 64 nodes activated with ReLU, and one output. If we perform the training and evaluation with the following code (i.e., the one you should have completed during the lab)
# ```
# #NumPy representation of the data frame (removing labels)
# df = df.to_numpy()
#
# #divide predictors from features
# X = #insert your code here
# y = #insert your code here
#
# seed = 7
# np.random.seed(seed)
#
# # split dataset in 75% for training and 25% for testing (500 -> 375,125)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)
#
# # split training in 70% for training and 30% for validating (375 -> 300,75)
# X_train, X_val, y_train, y_val = #insert your code here
#
# # Model creation (choose between tiny, small, medium, and large by using the appropriate function)
# model = create_model_large()
# history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# ```
#
# ### Which of the following answers is correct?
# - [ ] a. The validation loss is 0.
# - [x] b. The validation loss is > 0.25.
# - [ ] c. The validation loss is between 0.05 and 0.1.

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() 

#divide predictors from features
X = n_df[:, 1:]; # All features (cols from 2 to 8)
y = n_df[:, 0]; # Only predictors (col 1)

seed = 7
np.random.seed(seed)

# split dataset in 75% for training and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for training and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);#insert your code here

# Model creation (choose between tiny, small, medium, and large by using the appropriate function)
model = create_model_large(X_train.shape[1])
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 11.4267 - mean_absolute_error: 3.2974 - val_loss: 9.6204 - val_mean_absolute_error: 3.0165
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5846 - mean_absolute_error: 2.8409 - val_loss: 6.7851 - val_mean_absolute_error: 2.5005
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8087 - mean_absolute_error: 2.2938 - val_loss: 4.1775 - val_mean_absolute_error: 1.9167
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3393 - mean_absolute_error: 1.6730 - val_loss: 2.1298 - val_mean_absolute_error: 1.2860
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5826 - mean_absolute_error: 1.0573 - val_loss: 1.0541 - val_mean_absolute_error: 0.8478
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9060 - mean_absolute_error: 0.7726 - val_loss: 0.9462 - val_mean_absolute_error: 0.7731
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8029 - mean_absolute_error: 0.7158 - val_loss: 0.8392 - val_mean_absolute_error: 0.7241
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6677 - mean_absolute_error: 0.6529 - val_loss: 0.6923 - val_mean_absolute_error: 0.6686
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5671 - mean_absolute_error: 0.5995 - val_loss: 0.6125 - val_mean_absolute_error: 0.6272
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5087 - mean_absolute_error: 0.5602 - val_loss: 0.5527 - val_mean_absolute_error: 0.5922
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4701 - mean_absolute_error: 0.5323 - val_loss: 0.5046 - val_mean_absolute_error: 0.5623
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4394 - mean_absolute_error: 0.5116 - val_loss: 0.4678 - val_mean_absolute_error: 0.5376
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4220 - mean_absolute_error: 0.4996 - val_loss: 0.4375 - val_mean_absolute_error: 0.5166
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4004 - mean_absolute_error: 0.4878 - val_loss: 0.4127 - val_mean_absolute_error: 0.4996
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3835 - mean_absolute_error: 0.4804 - val_loss: 0.3908 - val_mean_absolute_error: 0.4850
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3701 - mean_absolute_error: 0.4728 - val_loss: 0.3751 - val_mean_absolute_error: 0.4749
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3597 - mean_absolute_error: 0.4674 - val_loss: 0.3654 - val_mean_absolute_error: 0.4695
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3504 - mean_absolute_error: 0.4616 - val_loss: 0.3571 - val_mean_absolute_error: 0.4639
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3429 - mean_absolute_error: 0.4555 - val_loss: 0.3510 - val_mean_absolute_error: 0.4601
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3373 - mean_absolute_error: 0.4528 - val_loss: 0.3452 - val_mean_absolute_error: 0.4566
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3316 - mean_absolute_error: 0.4497 - val_loss: 0.3395 - val_mean_absolute_error: 0.4536
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3288 - mean_absolute_error: 0.4494 - val_loss: 0.3386 - val_mean_absolute_error: 0.4518
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3247 - mean_absolute_error: 0.4473 - val_loss: 0.3363 - val_mean_absolute_error: 0.4511
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3238 - mean_absolute_error: 0.4461 - val_loss: 0.3312 - val_mean_absolute_error: 0.4467
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3165 - mean_absolute_error: 0.4411 - val_loss: 0.3271 - val_mean_absolute_error: 0.4440
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3142 - mean_absolute_error: 0.4402 - val_loss: 0.3261 - val_mean_absolute_error: 0.4451
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3151 - mean_absolute_error: 0.4430 - val_loss: 0.3275 - val_mean_absolute_error: 0.4465
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3077 - mean_absolute_error: 0.4357 - val_loss: 0.3205 - val_mean_absolute_error: 0.4403
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3087 - mean_absolute_error: 0.4354 - val_loss: 0.3195 - val_mean_absolute_error: 0.4399
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - mean_absolute_error: 0.4351 - val_loss: 0.3190 - val_mean_absolute_error: 0.4423
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3028 - mean_absolute_error: 0.4351 - val_loss: 0.3152 - val_mean_absolute_error: 0.4407
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3023 - mean_absolute_error: 0.4318 - val_loss: 0.3136 - val_mean_absolute_error: 0.4346
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3006 - mean_absolute_error: 0.4311 - val_loss: 0.3100 - val_mean_absolute_error: 0.4362
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2965 - mean_absolute_error: 0.4306 - val_loss: 0.3070 - val_mean_absolute_error: 0.4349
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2940 - mean_absolute_error: 0.4279 - val_loss: 0.3063 - val_mean_absolute_error: 0.4306
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2919 - mean_absolute_error: 0.4260 - val_loss: 0.3041 - val_mean_absolute_error: 0.4319
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2914 - mean_absolute_error: 0.4246 - val_loss: 0.3035 - val_mean_absolute_error: 0.4293
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2885 - mean_absolute_error: 0.4216 - val_loss: 0.3040 - val_mean_absolute_error: 0.4292
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3003 - mean_absolute_error: 0.4320 - val_loss: 0.3144 - val_mean_absolute_error: 0.4388
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2910 - mean_absolute_error: 0.4251 - val_loss: 0.3050 - val_mean_absolute_error: 0.4254
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2877 - mean_absolute_error: 0.4193 - val_loss: 0.2990 - val_mean_absolute_error: 0.4279
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2839 - mean_absolute_error: 0.4205 - val_loss: 0.2987 - val_mean_absolute_error: 0.4260
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2789 - mean_absolute_error: 0.4157 - val_loss: 0.2957 - val_mean_absolute_error: 0.4203
# Epoch 44/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2795 - mean_absolute_error: 0.4151 - val_loss: 0.2925 - val_mean_absolute_error: 0.4213
# Epoch 45/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2787 - mean_absolute_error: 0.4166 - val_loss: 0.2986 - val_mean_absolute_error: 0.4259
# Epoch 46/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2775 - mean_absolute_error: 0.4154 - val_loss: 0.2960 - val_mean_absolute_error: 0.4225
# Epoch 47/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2730 - mean_absolute_error: 0.4097 - val_loss: 0.2972 - val_mean_absolute_error: 0.4198
# Epoch 48/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2747 - mean_absolute_error: 0.4102 - val_loss: 0.2965 - val_mean_absolute_error: 0.4189
# Epoch 49/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2730 - mean_absolute_error: 0.4095 - val_loss: 0.2969 - val_mean_absolute_error: 0.4201
# Epoch 50/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2707 - mean_absolute_error: 0.4085 - val_loss: 0.2929 - val_mean_absolute_error: 0.4208
# Epoch 51/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2690 - mean_absolute_error: 0.4075 - val_loss: 0.2875 - val_mean_absolute_error: 0.4162
# Epoch 52/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2676 - mean_absolute_error: 0.4046 - val_loss: 0.2868 - val_mean_absolute_error: 0.4165
# Epoch 53/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2677 - mean_absolute_error: 0.4068 - val_loss: 0.2875 - val_mean_absolute_error: 0.4176
# Epoch 54/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2692 - mean_absolute_error: 0.4062 - val_loss: 0.2922 - val_mean_absolute_error: 0.4138
# Epoch 55/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2647 - mean_absolute_error: 0.4048 - val_loss: 0.2907 - val_mean_absolute_error: 0.4165
# Epoch 56/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2614 - mean_absolute_error: 0.4026 - val_loss: 0.2879 - val_mean_absolute_error: 0.4114
# Epoch 57/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2603 - mean_absolute_error: 0.3997 - val_loss: 0.2875 - val_mean_absolute_error: 0.4114
# Epoch 58/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2587 - mean_absolute_error: 0.3990 - val_loss: 0.2870 - val_mean_absolute_error: 0.4132
# Epoch 59/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2591 - mean_absolute_error: 0.3970 - val_loss: 0.2885 - val_mean_absolute_error: 0.4124
# Epoch 60/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2607 - mean_absolute_error: 0.4022 - val_loss: 0.2915 - val_mean_absolute_error: 0.4166
# Epoch 61/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2569 - mean_absolute_error: 0.3992 - val_loss: 0.2841 - val_mean_absolute_error: 0.4128
# Epoch 62/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2553 - mean_absolute_error: 0.3930 - val_loss: 0.2876 - val_mean_absolute_error: 0.4119
# Epoch 63/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2569 - mean_absolute_error: 0.3955 - val_loss: 0.2896 - val_mean_absolute_error: 0.4162
# Epoch 64/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2522 - mean_absolute_error: 0.3939 - val_loss: 0.2858 - val_mean_absolute_error: 0.4096
# Epoch 65/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2502 - mean_absolute_error: 0.3911 - val_loss: 0.2827 - val_mean_absolute_error: 0.4097
# Epoch 66/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2479 - mean_absolute_error: 0.3897 - val_loss: 0.2822 - val_mean_absolute_error: 0.4098
# Epoch 67/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2464 - mean_absolute_error: 0.3883 - val_loss: 0.2846 - val_mean_absolute_error: 0.4107
# Epoch 68/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2509 - mean_absolute_error: 0.3891 - val_loss: 0.2813 - val_mean_absolute_error: 0.4098
# Epoch 69/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2448 - mean_absolute_error: 0.3874 - val_loss: 0.2804 - val_mean_absolute_error: 0.4066
# Epoch 70/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2453 - mean_absolute_error: 0.3864 - val_loss: 0.2843 - val_mean_absolute_error: 0.4068
# Epoch 71/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2503 - mean_absolute_error: 0.3958 - val_loss: 0.2895 - val_mean_absolute_error: 0.4124
# Epoch 72/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2491 - mean_absolute_error: 0.3943 - val_loss: 0.2871 - val_mean_absolute_error: 0.4183
# Epoch 73/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2402 - mean_absolute_error: 0.3831 - val_loss: 0.2786 - val_mean_absolute_error: 0.4105
# Epoch 74/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2391 - mean_absolute_error: 0.3845 - val_loss: 0.2784 - val_mean_absolute_error: 0.4105
# Epoch 75/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2377 - mean_absolute_error: 0.3828 - val_loss: 0.2792 - val_mean_absolute_error: 0.4105
# Epoch 76/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2407 - mean_absolute_error: 0.3805 - val_loss: 0.2846 - val_mean_absolute_error: 0.4175
# Epoch 77/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2361 - mean_absolute_error: 0.3785 - val_loss: 0.2777 - val_mean_absolute_error: 0.4114
# Epoch 78/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2368 - mean_absolute_error: 0.3820 - val_loss: 0.2769 - val_mean_absolute_error: 0.4100
# Epoch 79/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2366 - mean_absolute_error: 0.3824 - val_loss: 0.2777 - val_mean_absolute_error: 0.4087
# Epoch 80/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2324 - mean_absolute_error: 0.3782 - val_loss: 0.2787 - val_mean_absolute_error: 0.4108
# Epoch 81/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2318 - mean_absolute_error: 0.3768 - val_loss: 0.2761 - val_mean_absolute_error: 0.4102
# Epoch 82/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2316 - mean_absolute_error: 0.3762 - val_loss: 0.2758 - val_mean_absolute_error: 0.4105
# Epoch 83/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2302 - mean_absolute_error: 0.3755 - val_loss: 0.2762 - val_mean_absolute_error: 0.4089
# Epoch 84/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2295 - mean_absolute_error: 0.3765 - val_loss: 0.2769 - val_mean_absolute_error: 0.4110
# Epoch 85/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2270 - mean_absolute_error: 0.3732 - val_loss: 0.2811 - val_mean_absolute_error: 0.4125
# Epoch 86/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2287 - mean_absolute_error: 0.3758 - val_loss: 0.2840 - val_mean_absolute_error: 0.4104
# Epoch 87/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2279 - mean_absolute_error: 0.3758 - val_loss: 0.2786 - val_mean_absolute_error: 0.4135
# Epoch 88/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2270 - mean_absolute_error: 0.3733 - val_loss: 0.2762 - val_mean_absolute_error: 0.4149
# Epoch 89/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2260 - mean_absolute_error: 0.3717 - val_loss: 0.2731 - val_mean_absolute_error: 0.4119
# Epoch 90/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2250 - mean_absolute_error: 0.3725 - val_loss: 0.2751 - val_mean_absolute_error: 0.4118
# Epoch 91/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2300 - mean_absolute_error: 0.3749 - val_loss: 0.2811 - val_mean_absolute_error: 0.4156
# Epoch 92/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2276 - mean_absolute_error: 0.3777 - val_loss: 0.2831 - val_mean_absolute_error: 0.4146
# Epoch 93/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2225 - mean_absolute_error: 0.3701 - val_loss: 0.2826 - val_mean_absolute_error: 0.4192
# Epoch 94/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2220 - mean_absolute_error: 0.3713 - val_loss: 0.2811 - val_mean_absolute_error: 0.4142
# Epoch 95/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2209 - mean_absolute_error: 0.3686 - val_loss: 0.2770 - val_mean_absolute_error: 0.4169
# Epoch 96/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2246 - mean_absolute_error: 0.3708 - val_loss: 0.2702 - val_mean_absolute_error: 0.4112
# Epoch 97/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2211 - mean_absolute_error: 0.3691 - val_loss: 0.2728 - val_mean_absolute_error: 0.4129
# Epoch 98/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2267 - mean_absolute_error: 0.3765 - val_loss: 0.2833 - val_mean_absolute_error: 0.4157
# Epoch 99/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2220 - mean_absolute_error: 0.3684 - val_loss: 0.2915 - val_mean_absolute_error: 0.4281
# Epoch 100/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2150 - mean_absolute_error: 0.3638 - val_loss: 0.2838 - val_mean_absolute_error: 0.4195
# Epoch 101/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2167 - mean_absolute_error: 0.3665 - val_loss: 0.2832 - val_mean_absolute_error: 0.4223
# Epoch 102/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2141 - mean_absolute_error: 0.3631 - val_loss: 0.2889 - val_mean_absolute_error: 0.4255
# Epoch 103/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2156 - mean_absolute_error: 0.3652 - val_loss: 0.2894 - val_mean_absolute_error: 0.4217
# Epoch 104/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2174 - mean_absolute_error: 0.3672 - val_loss: 0.2862 - val_mean_absolute_error: 0.4205
# Epoch 105/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2163 - mean_absolute_error: 0.3645 - val_loss: 0.2858 - val_mean_absolute_error: 0.4230
# Epoch 106/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2185 - mean_absolute_error: 0.3655 - val_loss: 0.2831 - val_mean_absolute_error: 0.4174
# Epoch 107/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2194 - mean_absolute_error: 0.3666 - val_loss: 0.2878 - val_mean_absolute_error: 0.4274
# Epoch 108/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2165 - mean_absolute_error: 0.3695 - val_loss: 0.2860 - val_mean_absolute_error: 0.4202
# Epoch 109/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2128 - mean_absolute_error: 0.3607 - val_loss: 0.2964 - val_mean_absolute_error: 0.4332
# Epoch 110/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2104 - mean_absolute_error: 0.3588 - val_loss: 0.2891 - val_mean_absolute_error: 0.4201
# Epoch 111/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2097 - mean_absolute_error: 0.3583 - val_loss: 0.2832 - val_mean_absolute_error: 0.4205
# Epoch 112/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2104 - mean_absolute_error: 0.3583 - val_loss: 0.2823 - val_mean_absolute_error: 0.4194
# Epoch 113/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2072 - mean_absolute_error: 0.3579 - val_loss: 0.2884 - val_mean_absolute_error: 0.4225
# Epoch 114/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2063 - mean_absolute_error: 0.3564 - val_loss: 0.2936 - val_mean_absolute_error: 0.4292
# Epoch 115/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2112 - mean_absolute_error: 0.3596 - val_loss: 0.2891 - val_mean_absolute_error: 0.4214
# Epoch 116/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2070 - mean_absolute_error: 0.3562 - val_loss: 0.2827 - val_mean_absolute_error: 0.4170
# Epoch 117/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2130 - mean_absolute_error: 0.3650 - val_loss: 0.2763 - val_mean_absolute_error: 0.4156
# Epoch 118/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2080 - mean_absolute_error: 0.3551 - val_loss: 0.2872 - val_mean_absolute_error: 0.4238
# Epoch 119/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2032 - mean_absolute_error: 0.3539 - val_loss: 0.2842 - val_mean_absolute_error: 0.4182
# Epoch 120/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2111 - mean_absolute_error: 0.3630 - val_loss: 0.2846 - val_mean_absolute_error: 0.4215
# Epoch 121/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2154 - mean_absolute_error: 0.3650 - val_loss: 0.2871 - val_mean_absolute_error: 0.4240
# Epoch 122/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2085 - mean_absolute_error: 0.3601 - val_loss: 0.2886 - val_mean_absolute_error: 0.4213
# Epoch 123/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2108 - mean_absolute_error: 0.3603 - val_loss: 0.2940 - val_mean_absolute_error: 0.4312
# Epoch 124/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2097 - mean_absolute_error: 0.3586 - val_loss: 0.2901 - val_mean_absolute_error: 0.4258
# Epoch 125/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2002 - mean_absolute_error: 0.3520 - val_loss: 0.2992 - val_mean_absolute_error: 0.4351
# Epoch 126/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2059 - mean_absolute_error: 0.3542 - val_loss: 0.2908 - val_mean_absolute_error: 0.4247
# Epoch 127/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2033 - mean_absolute_error: 0.3555 - val_loss: 0.2850 - val_mean_absolute_error: 0.4228
# Epoch 128/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1998 - mean_absolute_error: 0.3521 - val_loss: 0.2840 - val_mean_absolute_error: 0.4222
# Epoch 129/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1992 - mean_absolute_error: 0.3509 - val_loss: 0.2852 - val_mean_absolute_error: 0.4232
# Epoch 130/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2038 - mean_absolute_error: 0.3537 - val_loss: 0.2897 - val_mean_absolute_error: 0.4230
# Epoch 131/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1997 - mean_absolute_error: 0.3517 - val_loss: 0.2996 - val_mean_absolute_error: 0.4319
# Epoch 132/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2018 - mean_absolute_error: 0.3538 - val_loss: 0.2956 - val_mean_absolute_error: 0.4307
# Epoch 133/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2001 - mean_absolute_error: 0.3510 - val_loss: 0.2955 - val_mean_absolute_error: 0.4317
# Epoch 134/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1967 - mean_absolute_error: 0.3479 - val_loss: 0.2925 - val_mean_absolute_error: 0.4274
# Epoch 135/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1957 - mean_absolute_error: 0.3485 - val_loss: 0.2932 - val_mean_absolute_error: 0.4273
# Epoch 136/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1959 - mean_absolute_error: 0.3474 - val_loss: 0.2877 - val_mean_absolute_error: 0.4232
# Epoch 137/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1952 - mean_absolute_error: 0.3472 - val_loss: 0.2898 - val_mean_absolute_error: 0.4250
# Epoch 138/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1976 - mean_absolute_error: 0.3511 - val_loss: 0.2931 - val_mean_absolute_error: 0.4300
# Epoch 139/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1965 - mean_absolute_error: 0.3485 - val_loss: 0.2985 - val_mean_absolute_error: 0.4340
# Epoch 140/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1971 - mean_absolute_error: 0.3498 - val_loss: 0.2901 - val_mean_absolute_error: 0.4265
# Epoch 141/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1927 - mean_absolute_error: 0.3470 - val_loss: 0.2959 - val_mean_absolute_error: 0.4321
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1927 - mean_absolute_error: 0.3457 - val_loss: 0.2963 - val_mean_absolute_error: 0.4323
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1944 - mean_absolute_error: 0.3477 - val_loss: 0.2905 - val_mean_absolute_error: 0.4273
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1937 - mean_absolute_error: 0.3454 - val_loss: 0.2957 - val_mean_absolute_error: 0.4298
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1927 - mean_absolute_error: 0.3443 - val_loss: 0.3002 - val_mean_absolute_error: 0.4328
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1924 - mean_absolute_error: 0.3463 - val_loss: 0.2963 - val_mean_absolute_error: 0.4311
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1931 - mean_absolute_error: 0.3467 - val_loss: 0.2959 - val_mean_absolute_error: 0.4321
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1875 - mean_absolute_error: 0.3409 - val_loss: 0.2964 - val_mean_absolute_error: 0.4323
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1919 - mean_absolute_error: 0.3442 - val_loss: 0.3003 - val_mean_absolute_error: 0.4361
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1914 - mean_absolute_error: 0.3431 - val_loss: 0.3051 - val_mean_absolute_error: 0.4394

# %% [markdown]
# ## Question 2 (question 6 of reinforced learning quiz)
# Consider a regression task using Deep Neural Networks (DNNs) and consider the dataset NO2 (the same code as the ML laboratory). Create a DNN consisting of 10 inputs, 3 hidden layers of 64 nodes activated with ReLU, and one output. If we perform the training and evaluation with the following code (i.e., the one you should have completed during the lab)
# ```
# #NumPy representation of the data frame (removing labels)
# df = df.to_numpy()
#
# #divide predictors from features
# X = #insert your code here
# y = #insert your code here
#
# seed = 7
# np.random.seed(seed)
#
# # split dataset in 75% for training and 25% for testing (500 -> 375,125)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)
#
# # split training in 70% for training and 30% for validating (375 -> 300,75)
# X_train, X_val, y_train, y_val = #insert your code here
#
# # Model creation (choose between tiny, small, medium, and large by using the appropriate function)
# model = create_model_large()
# history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# ```
#
# ### Which of the following answers is correct?
# - [ ] a.
# - [ ] b.
# - [ ] c.

# %%
#NumPy representation of the data frame (removing labels)
df = df.to_numpy() 

#divide predictors from features
X = #insert your code here 
y = #insert your code here

seed = 7
np.random.seed(seed)

# split dataset in 75% for training and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for training and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = #insert your code here

# Model creation (choose between tiny, small, medium, and large by using the appropriate function)
model = create_model_large()
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
