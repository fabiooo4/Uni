# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(40, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), all activation functions should be ReLU.

# %%
def create_model_tiny(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(3, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium(input_size):
    # create model
    model = Sequential()    
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matrix among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() #n_df=n_df.values

#divide predictors from features
X = n_df[:, 1:]; # All features (cols from 2 to 8)
y = n_df[:, 0]; # Only predictors (col 1)

print("df shape ", n_df.shape)
print("X shape ", X.shape)
print("y shape ", y.shape)

seed = 7
np.random.seed(seed)

# split dataset in 77% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);#insert your code here

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_large(X_train.shape[1])
model.summary()
# Out:
# df shape  (500, 8)
# X shape  (500, 7)
# y shape  (500,)
# /nix/store/lm1dh50a59200g0c4nl175nysy9nxrgh-python3-3.13.11-env/lib/python3.13/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                │ (None, 10)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 30)             │           330 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 40)             │         1,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │            41 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,691 (6.61 KB)
#  Trainable params: 1,691 (6.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 13.1659 - mean_absolute_error: 3.5298 - val_loss: 11.7311 - val_mean_absolute_error: 3.3171
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.0947 - mean_absolute_error: 3.2201 - val_loss: 9.7243 - val_mean_absolute_error: 2.9921
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9432 - mean_absolute_error: 2.8591 - val_loss: 7.5416 - val_mean_absolute_error: 2.5936
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6308 - mean_absolute_error: 2.4018 - val_loss: 5.2720 - val_mean_absolute_error: 2.1021
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3492 - mean_absolute_error: 1.8768 - val_loss: 3.2671 - val_mean_absolute_error: 1.6114
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5473 - mean_absolute_error: 1.3802 - val_loss: 1.9203 - val_mean_absolute_error: 1.2080
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5354 - mean_absolute_error: 1.0277 - val_loss: 1.4069 - val_mean_absolute_error: 0.9677
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2663 - mean_absolute_error: 0.8976 - val_loss: 1.2080 - val_mean_absolute_error: 0.8717
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0786 - mean_absolute_error: 0.8363 - val_loss: 0.9560 - val_mean_absolute_error: 0.7896
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9011 - mean_absolute_error: 0.7619 - val_loss: 0.8208 - val_mean_absolute_error: 0.7317
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8085 - mean_absolute_error: 0.7215 - val_loss: 0.7417 - val_mean_absolute_error: 0.6952
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7343 - mean_absolute_error: 0.6861 - val_loss: 0.6679 - val_mean_absolute_error: 0.6609
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6723 - mean_absolute_error: 0.6534 - val_loss: 0.6144 - val_mean_absolute_error: 0.6333
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6293 - mean_absolute_error: 0.6303 - val_loss: 0.5772 - val_mean_absolute_error: 0.6147
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5921 - mean_absolute_error: 0.6097 - val_loss: 0.5484 - val_mean_absolute_error: 0.5986
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5584 - mean_absolute_error: 0.5922 - val_loss: 0.5215 - val_mean_absolute_error: 0.5817
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5288 - mean_absolute_error: 0.5735 - val_loss: 0.4994 - val_mean_absolute_error: 0.5659
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5054 - mean_absolute_error: 0.5587 - val_loss: 0.4796 - val_mean_absolute_error: 0.5499
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4832 - mean_absolute_error: 0.5450 - val_loss: 0.4623 - val_mean_absolute_error: 0.5368
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4608 - mean_absolute_error: 0.5314 - val_loss: 0.4478 - val_mean_absolute_error: 0.5274
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4413 - mean_absolute_error: 0.5194 - val_loss: 0.4321 - val_mean_absolute_error: 0.5178
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4244 - mean_absolute_error: 0.5092 - val_loss: 0.4193 - val_mean_absolute_error: 0.5094
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4128 - mean_absolute_error: 0.5018 - val_loss: 0.4091 - val_mean_absolute_error: 0.5018
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3993 - mean_absolute_error: 0.4932 - val_loss: 0.4021 - val_mean_absolute_error: 0.4954
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3869 - mean_absolute_error: 0.4866 - val_loss: 0.3955 - val_mean_absolute_error: 0.4887
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3785 - mean_absolute_error: 0.4800 - val_loss: 0.3875 - val_mean_absolute_error: 0.4836
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3701 - mean_absolute_error: 0.4742 - val_loss: 0.3808 - val_mean_absolute_error: 0.4772
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3601 - mean_absolute_error: 0.4681 - val_loss: 0.3757 - val_mean_absolute_error: 0.4734
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3547 - mean_absolute_error: 0.4647 - val_loss: 0.3704 - val_mean_absolute_error: 0.4671
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3454 - mean_absolute_error: 0.4602 - val_loss: 0.3689 - val_mean_absolute_error: 0.4672
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3387 - mean_absolute_error: 0.4553 - val_loss: 0.3590 - val_mean_absolute_error: 0.4614
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3355 - mean_absolute_error: 0.4524 - val_loss: 0.3543 - val_mean_absolute_error: 0.4604
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3288 - mean_absolute_error: 0.4479 - val_loss: 0.3516 - val_mean_absolute_error: 0.4580
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3239 - mean_absolute_error: 0.4461 - val_loss: 0.3522 - val_mean_absolute_error: 0.4589
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3199 - mean_absolute_error: 0.4449 - val_loss: 0.3474 - val_mean_absolute_error: 0.4566
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3146 - mean_absolute_error: 0.4412 - val_loss: 0.3456 - val_mean_absolute_error: 0.4559
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3115 - mean_absolute_error: 0.4378 - val_loss: 0.3455 - val_mean_absolute_error: 0.4584
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3084 - mean_absolute_error: 0.4339 - val_loss: 0.3427 - val_mean_absolute_error: 0.4575
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3024 - mean_absolute_error: 0.4285 - val_loss: 0.3430 - val_mean_absolute_error: 0.4550
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2981 - mean_absolute_error: 0.4269 - val_loss: 0.3401 - val_mean_absolute_error: 0.4540
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2961 - mean_absolute_error: 0.4247 - val_loss: 0.3395 - val_mean_absolute_error: 0.4547
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2944 - mean_absolute_error: 0.4242 - val_loss: 0.3378 - val_mean_absolute_error: 0.4515
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2900 - mean_absolute_error: 0.4204 - val_loss: 0.3352 - val_mean_absolute_error: 0.4519
# Epoch 44/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2873 - mean_absolute_error: 0.4192 - val_loss: 0.3358 - val_mean_absolute_error: 0.4521
# Epoch 45/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2868 - mean_absolute_error: 0.4172 - val_loss: 0.3361 - val_mean_absolute_error: 0.4535
# Epoch 46/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2867 - mean_absolute_error: 0.4182 - val_loss: 0.3344 - val_mean_absolute_error: 0.4521
# Epoch 47/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2830 - mean_absolute_error: 0.4146 - val_loss: 0.3361 - val_mean_absolute_error: 0.4473
# Epoch 48/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2787 - mean_absolute_error: 0.4122 - val_loss: 0.3344 - val_mean_absolute_error: 0.4493
# Epoch 49/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2847 - mean_absolute_error: 0.4176 - val_loss: 0.3345 - val_mean_absolute_error: 0.4499
# Epoch 50/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2772 - mean_absolute_error: 0.4097 - val_loss: 0.3377 - val_mean_absolute_error: 0.4461
# Epoch 51/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2730 - mean_absolute_error: 0.4055 - val_loss: 0.3355 - val_mean_absolute_error: 0.4477
# Epoch 52/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2767 - mean_absolute_error: 0.4102 - val_loss: 0.3355 - val_mean_absolute_error: 0.4474
# Epoch 53/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2700 - mean_absolute_error: 0.4058 - val_loss: 0.3334 - val_mean_absolute_error: 0.4437
# Epoch 54/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2712 - mean_absolute_error: 0.4049 - val_loss: 0.3307 - val_mean_absolute_error: 0.4423
# Epoch 55/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2699 - mean_absolute_error: 0.4055 - val_loss: 0.3282 - val_mean_absolute_error: 0.4417
# Epoch 56/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2666 - mean_absolute_error: 0.4021 - val_loss: 0.3276 - val_mean_absolute_error: 0.4394
# Epoch 57/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2659 - mean_absolute_error: 0.4008 - val_loss: 0.3292 - val_mean_absolute_error: 0.4408
# Epoch 58/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2658 - mean_absolute_error: 0.4004 - val_loss: 0.3275 - val_mean_absolute_error: 0.4382
# Epoch 59/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2638 - mean_absolute_error: 0.3997 - val_loss: 0.3320 - val_mean_absolute_error: 0.4414
# Epoch 60/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2614 - mean_absolute_error: 0.3992 - val_loss: 0.3306 - val_mean_absolute_error: 0.4422
# Epoch 61/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2622 - mean_absolute_error: 0.3997 - val_loss: 0.3287 - val_mean_absolute_error: 0.4410
# Epoch 62/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2587 - mean_absolute_error: 0.3959 - val_loss: 0.3294 - val_mean_absolute_error: 0.4410
# Epoch 63/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2591 - mean_absolute_error: 0.3959 - val_loss: 0.3291 - val_mean_absolute_error: 0.4424
# Epoch 64/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2588 - mean_absolute_error: 0.3961 - val_loss: 0.3286 - val_mean_absolute_error: 0.4408
# Epoch 65/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2567 - mean_absolute_error: 0.3953 - val_loss: 0.3273 - val_mean_absolute_error: 0.4394
# Epoch 66/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2538 - mean_absolute_error: 0.3909 - val_loss: 0.3285 - val_mean_absolute_error: 0.4399
# Epoch 67/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2533 - mean_absolute_error: 0.3902 - val_loss: 0.3262 - val_mean_absolute_error: 0.4405
# Epoch 68/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2590 - mean_absolute_error: 0.3996 - val_loss: 0.3259 - val_mean_absolute_error: 0.4399
# Epoch 69/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2556 - mean_absolute_error: 0.3943 - val_loss: 0.3296 - val_mean_absolute_error: 0.4408
# Epoch 70/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2522 - mean_absolute_error: 0.3896 - val_loss: 0.3242 - val_mean_absolute_error: 0.4381
# Epoch 71/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2501 - mean_absolute_error: 0.3893 - val_loss: 0.3243 - val_mean_absolute_error: 0.4367
# Epoch 72/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2497 - mean_absolute_error: 0.3871 - val_loss: 0.3228 - val_mean_absolute_error: 0.4371
# Epoch 73/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2496 - mean_absolute_error: 0.3890 - val_loss: 0.3226 - val_mean_absolute_error: 0.4365
# Epoch 74/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2464 - mean_absolute_error: 0.3868 - val_loss: 0.3205 - val_mean_absolute_error: 0.4357
# Epoch 75/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2458 - mean_absolute_error: 0.3866 - val_loss: 0.3200 - val_mean_absolute_error: 0.4355
# Epoch 76/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2462 - mean_absolute_error: 0.3851 - val_loss: 0.3190 - val_mean_absolute_error: 0.4339
# Epoch 77/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2437 - mean_absolute_error: 0.3820 - val_loss: 0.3196 - val_mean_absolute_error: 0.4322
# Epoch 78/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2432 - mean_absolute_error: 0.3815 - val_loss: 0.3218 - val_mean_absolute_error: 0.4334
# Epoch 79/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2415 - mean_absolute_error: 0.3803 - val_loss: 0.3214 - val_mean_absolute_error: 0.4333
# Epoch 80/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2409 - mean_absolute_error: 0.3802 - val_loss: 0.3203 - val_mean_absolute_error: 0.4332
# Epoch 81/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2408 - mean_absolute_error: 0.3795 - val_loss: 0.3183 - val_mean_absolute_error: 0.4306
# Epoch 82/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2405 - mean_absolute_error: 0.3789 - val_loss: 0.3175 - val_mean_absolute_error: 0.4309
# Epoch 83/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2399 - mean_absolute_error: 0.3808 - val_loss: 0.3173 - val_mean_absolute_error: 0.4324
# Epoch 84/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2367 - mean_absolute_error: 0.3773 - val_loss: 0.3182 - val_mean_absolute_error: 0.4315
# Epoch 85/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2367 - mean_absolute_error: 0.3746 - val_loss: 0.3175 - val_mean_absolute_error: 0.4290
# Epoch 86/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2351 - mean_absolute_error: 0.3752 - val_loss: 0.3172 - val_mean_absolute_error: 0.4297
# Epoch 87/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2398 - mean_absolute_error: 0.3779 - val_loss: 0.3183 - val_mean_absolute_error: 0.4322
# Epoch 88/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2337 - mean_absolute_error: 0.3746 - val_loss: 0.3171 - val_mean_absolute_error: 0.4356
# Epoch 89/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2350 - mean_absolute_error: 0.3765 - val_loss: 0.3146 - val_mean_absolute_error: 0.4297
# Epoch 90/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2316 - mean_absolute_error: 0.3717 - val_loss: 0.3135 - val_mean_absolute_error: 0.4287
# Epoch 91/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2344 - mean_absolute_error: 0.3756 - val_loss: 0.3147 - val_mean_absolute_error: 0.4309
# Epoch 92/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2302 - mean_absolute_error: 0.3711 - val_loss: 0.3133 - val_mean_absolute_error: 0.4286
# Epoch 93/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2318 - mean_absolute_error: 0.3730 - val_loss: 0.3154 - val_mean_absolute_error: 0.4311
# Epoch 94/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2305 - mean_absolute_error: 0.3720 - val_loss: 0.3157 - val_mean_absolute_error: 0.4300
# Epoch 95/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2271 - mean_absolute_error: 0.3674 - val_loss: 0.3151 - val_mean_absolute_error: 0.4273
# Epoch 96/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2268 - mean_absolute_error: 0.3665 - val_loss: 0.3146 - val_mean_absolute_error: 0.4272
# Epoch 97/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2339 - mean_absolute_error: 0.3742 - val_loss: 0.3136 - val_mean_absolute_error: 0.4302
# Epoch 98/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2377 - mean_absolute_error: 0.3772 - val_loss: 0.3185 - val_mean_absolute_error: 0.4329
# Epoch 99/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2252 - mean_absolute_error: 0.3691 - val_loss: 0.3182 - val_mean_absolute_error: 0.4361
# Epoch 100/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2254 - mean_absolute_error: 0.3694 - val_loss: 0.3197 - val_mean_absolute_error: 0.4342
# Epoch 101/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2259 - mean_absolute_error: 0.3691 - val_loss: 0.3186 - val_mean_absolute_error: 0.4352
# Epoch 102/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2239 - mean_absolute_error: 0.3679 - val_loss: 0.3184 - val_mean_absolute_error: 0.4344
# Epoch 103/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2236 - mean_absolute_error: 0.3679 - val_loss: 0.3173 - val_mean_absolute_error: 0.4321
# Epoch 104/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2217 - mean_absolute_error: 0.3652 - val_loss: 0.3153 - val_mean_absolute_error: 0.4296
# Epoch 105/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2206 - mean_absolute_error: 0.3644 - val_loss: 0.3160 - val_mean_absolute_error: 0.4322
# Epoch 106/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2208 - mean_absolute_error: 0.3651 - val_loss: 0.3165 - val_mean_absolute_error: 0.4316
# Epoch 107/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2176 - mean_absolute_error: 0.3614 - val_loss: 0.3155 - val_mean_absolute_error: 0.4278
# Epoch 108/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2238 - mean_absolute_error: 0.3648 - val_loss: 0.3156 - val_mean_absolute_error: 0.4288
# Epoch 109/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2223 - mean_absolute_error: 0.3660 - val_loss: 0.3172 - val_mean_absolute_error: 0.4331
# Epoch 110/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2177 - mean_absolute_error: 0.3614 - val_loss: 0.3191 - val_mean_absolute_error: 0.4331
# Epoch 111/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2194 - mean_absolute_error: 0.3639 - val_loss: 0.3159 - val_mean_absolute_error: 0.4308
# Epoch 112/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2166 - mean_absolute_error: 0.3620 - val_loss: 0.3149 - val_mean_absolute_error: 0.4307
# Epoch 113/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2203 - mean_absolute_error: 0.3665 - val_loss: 0.3175 - val_mean_absolute_error: 0.4292
# Epoch 114/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2128 - mean_absolute_error: 0.3557 - val_loss: 0.3176 - val_mean_absolute_error: 0.4263
# Epoch 115/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2159 - mean_absolute_error: 0.3579 - val_loss: 0.3159 - val_mean_absolute_error: 0.4266
# Epoch 116/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2138 - mean_absolute_error: 0.3577 - val_loss: 0.3175 - val_mean_absolute_error: 0.4304
# Epoch 117/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2119 - mean_absolute_error: 0.3561 - val_loss: 0.3177 - val_mean_absolute_error: 0.4302
# Epoch 118/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2112 - mean_absolute_error: 0.3549 - val_loss: 0.3175 - val_mean_absolute_error: 0.4299
# Epoch 119/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2111 - mean_absolute_error: 0.3548 - val_loss: 0.3179 - val_mean_absolute_error: 0.4286
# Epoch 120/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2123 - mean_absolute_error: 0.3553 - val_loss: 0.3194 - val_mean_absolute_error: 0.4320
# Epoch 121/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2136 - mean_absolute_error: 0.3589 - val_loss: 0.3217 - val_mean_absolute_error: 0.4334
# Epoch 122/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2112 - mean_absolute_error: 0.3564 - val_loss: 0.3251 - val_mean_absolute_error: 0.4355
# Epoch 123/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2094 - mean_absolute_error: 0.3562 - val_loss: 0.3231 - val_mean_absolute_error: 0.4350
# Epoch 124/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2097 - mean_absolute_error: 0.3558 - val_loss: 0.3181 - val_mean_absolute_error: 0.4306
# Epoch 125/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2120 - mean_absolute_error: 0.3576 - val_loss: 0.3153 - val_mean_absolute_error: 0.4294
# Epoch 126/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2063 - mean_absolute_error: 0.3558 - val_loss: 0.3193 - val_mean_absolute_error: 0.4372
# Epoch 127/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2081 - mean_absolute_error: 0.3567 - val_loss: 0.3178 - val_mean_absolute_error: 0.4338
# Epoch 128/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2061 - mean_absolute_error: 0.3523 - val_loss: 0.3168 - val_mean_absolute_error: 0.4284
# Epoch 129/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2061 - mean_absolute_error: 0.3497 - val_loss: 0.3164 - val_mean_absolute_error: 0.4268
# Epoch 130/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2081 - mean_absolute_error: 0.3522 - val_loss: 0.3166 - val_mean_absolute_error: 0.4256
# Epoch 131/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2076 - mean_absolute_error: 0.3512 - val_loss: 0.3122 - val_mean_absolute_error: 0.4237
# Epoch 132/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2053 - mean_absolute_error: 0.3513 - val_loss: 0.3114 - val_mean_absolute_error: 0.4270
# Epoch 133/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2028 - mean_absolute_error: 0.3489 - val_loss: 0.3147 - val_mean_absolute_error: 0.4290
# Epoch 134/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2038 - mean_absolute_error: 0.3493 - val_loss: 0.3162 - val_mean_absolute_error: 0.4272
# Epoch 135/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2018 - mean_absolute_error: 0.3465 - val_loss: 0.3199 - val_mean_absolute_error: 0.4294
# Epoch 136/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2017 - mean_absolute_error: 0.3471 - val_loss: 0.3179 - val_mean_absolute_error: 0.4249
# Epoch 137/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2006 - mean_absolute_error: 0.3460 - val_loss: 0.3153 - val_mean_absolute_error: 0.4270
# Epoch 138/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2010 - mean_absolute_error: 0.3463 - val_loss: 0.3138 - val_mean_absolute_error: 0.4283
# Epoch 139/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2019 - mean_absolute_error: 0.3477 - val_loss: 0.3149 - val_mean_absolute_error: 0.4285
# Epoch 140/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1985 - mean_absolute_error: 0.3442 - val_loss: 0.3197 - val_mean_absolute_error: 0.4258
# Epoch 141/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2044 - mean_absolute_error: 0.3493 - val_loss: 0.3195 - val_mean_absolute_error: 0.4257
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2046 - mean_absolute_error: 0.3471 - val_loss: 0.3206 - val_mean_absolute_error: 0.4336
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1982 - mean_absolute_error: 0.3425 - val_loss: 0.3162 - val_mean_absolute_error: 0.4288
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2012 - mean_absolute_error: 0.3471 - val_loss: 0.3172 - val_mean_absolute_error: 0.4296
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2015 - mean_absolute_error: 0.3485 - val_loss: 0.3136 - val_mean_absolute_error: 0.4266
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2072 - mean_absolute_error: 0.3532 - val_loss: 0.3191 - val_mean_absolute_error: 0.4332
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1975 - mean_absolute_error: 0.3398 - val_loss: 0.3175 - val_mean_absolute_error: 0.4310
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1986 - mean_absolute_error: 0.3456 - val_loss: 0.3172 - val_mean_absolute_error: 0.4304
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1963 - mean_absolute_error: 0.3431 - val_loss: 0.3110 - val_mean_absolute_error: 0.4221
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2004 - mean_absolute_error: 0.3459 - val_loss: 0.3106 - val_mean_absolute_error: 0.4240

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ffeb74d7740> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# rmse :  0.5366278563205528   nrmse :  0.26572606779235514

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()
